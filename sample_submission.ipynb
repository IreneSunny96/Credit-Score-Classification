# %% [markdown]
# # Credit Score Classification : Basic Example Notebook
#
# This is an example notebook for the FML Kaggle Challenge. Here are some basic steps to preprocess, train et generate predictions.
# ### Caution: Some of the steps here are just explanatories, you will still need to change and add steps to perform well in the challenge

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Reading the Dataset

# %%
train_data = pd.read_csv('train_set.csv', index_col=0)
test_data = pd.read_csv('test_set.csv', index_col=0)

# %%
test_data
# Out:
#         Customer_ID  Month                 Name   Age          SSN  \
# ID
# 68757         25026      4  Aradhana Aravindanw  23.0    8170608.0
# 113371        33960      2              Kanekoe  43.0  819245756.0
# 154933        34269      8             Lucianam  45.0  767367303.0
# 77449         24946      8  Lefteris Papadimasd  32.0  794097808.0
# 60732          9532      7            Tom Halss  34.0  399035425.0
# ...             ...    ...                  ...   ...          ...
# 129058        40969      5      Rick Rothackert  27.0  534994357.0
# 108661        16367      8            Jenniferq  53.0  634716210.0
# 120097        39091      8   Philipp Halstrickm  27.0  587143010.0
# 109412        18783      3               Jeffsp  26.0  602146009.0
# 105046         7167      5       Anjuli Daviest  38.0   57885600.0
#
#         Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ID
# 68757       Lawyer      88752.260            7109.021667                5.0
# 113371    Mechanic      87745.920            7166.160000                0.0
# 154933      Lawyer       8974.555             783.879583               10.0
# 77449      Manager      17091.960            1182.330000               10.0
# 60732    Developer      49128.900            4231.075000                8.0
# ...            ...            ...                    ...                ...
# 129058   Architect      39089.090            3089.424167                2.0
# 108661      Lawyer      54426.180            4546.515000                4.0
# 120097    Mechanic      58508.760            4722.730000                6.0
# 109412      Lawyer      20012.870            1830.739167                7.0
# 105046  Accountant      19323.400            1749.283333               10.0
#
#         Num_Credit_Card  ...  Num_Credit_Inquiries  Credit_Mix  \
# ID                       ...
# 68757               6.0  ...                   8.0        Good
# 113371              1.0  ...                   1.0        Good
# 154933              8.0  ...                   7.0         Bad
# 77449               8.0  ...                  11.0         Bad
# 60732               3.0  ...                   7.0    Standard
# ...                 ...  ...                   ...         ...
# 129058              4.0  ...                   3.0        Good
# 108661              6.0  ...                   6.0    Standard
# 120097              5.0  ...                   7.0    Standard
# 109412              8.0  ...                  11.0         Bad
# 105046              5.0  ...                   7.0         Bad
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# ID
# 68757           1180.26                 36.713885               221.0
# 113371           207.00                 36.121435               245.0
# 154933          1660.14                 33.883240               202.0
# 77449           4047.31                 40.077930               101.0
# 60732           2574.10                 29.415814               172.0
# ...                 ...                       ...                 ...
# 129058           474.96                 38.711520               228.0
# 108661           865.04                 29.607863               366.0
# 120097          1048.25                 26.961976               179.0
# 109412          3500.17                 33.280902                 9.0
# 105046          3033.25                 30.336109               104.0
#
#         Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# ID
# 68757                      No            72.524443               85.233292
# 113371                     NM             0.000000              115.395977
# 154933                    Yes            30.443262                0.000000
# 77449                     Yes            54.857946               47.483510
# 60732                     Yes           169.529221               27.492075
# ...                       ...                  ...                     ...
# 129058                     No            53.515554               56.359550
# 108661                     No           137.767461               65.206009
# 120097                    Yes           164.199022               91.230386
# 109412                    Yes            59.458388               51.512374
# 105046                    Yes            99.101347               14.365014
#
#                        Payment_Behaviour  Monthly_Balance
# ID
# 68757   High_spent_Medium_value_payments       290.805548
# 113371    Low_spent_Small_value_payments       639.825556
# 154933    Low_spent_Small_value_payments       280.503360
# 77449     Low_spent_Small_value_payments       282.354884
# 60732    High_spent_Large_value_payments       399.169994
# ...                                  ...              ...
# 129058    Low_spent_Small_value_payments       232.453130
# 108661  High_spent_Medium_value_payments       445.876920
# 120097  High_spent_Medium_value_payments       383.913135
# 109412  High_spent_Medium_value_payments       319.545308
# 105046    Low_spent_Small_value_payments       252.392668
#
# [30000 rows x 26 columns]

# %% [markdown]
# ## Selecting Features and Encoding

# %% [markdown]
# In this example, we only consider numerical values but some categorical values might be of help

# %%
categorical_columns = ['Credit_Mix',
                      'Month',
                      'Occupation',
                      'Payment_Behaviour',
                      'Payment_of_Min_Amount',
                      'Type_of_Loan',
                      'Customer_ID',
                      'Name',
                      'SSN']


numerical_columns = ['Age',
                            'Num_Bank_Accounts',
                            'Num_Credit_Card',
                            'Interest_Rate',
                            'Num_of_Loan',
                            'Delay_from_due_date',
                            'Num_of_Delayed_Payment',
                            'Num_Credit_Inquiries',
                            'Credit_History_Age',
                            'Credit_Utilization_Ratio',
                           'Annual_Income',
                           'Monthly_Inhand_Salary', 
                           'Changed_Credit_Limit', 
                           'Outstanding_Debt', 
                           'Total_EMI_per_month',
                           'Amount_invested_monthly', 
                           'Monthly_Balance']

# Feature to predict
label_to_predict = 'Credit_Score'

# %%
X_train = train_data[numerical_columns]
X_test  = test_data[numerical_columns]

# %% [markdown]
# ## Begin Training

# %% [markdown]
# We start training a simple DecisionTree model, you will need to think about which model to use to outperform this one and which hyperparameters to use

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

# %%
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_data[label_to_predict]).astype(int)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict(X_val)
accuracy_score(y_pred, y_val)
# Out:
# 0.721

# %% [markdown]
# ## Generating the Submission

# %% [markdown]
# Below you will find a function that does the predictions for the test set and generates a submission, this submission is to be uploaded to kaggle to update the leaderboard

# %%
def generate_submission():
    list_of_predictions = model.predict(X_test)
    preds = label_encoder.inverse_transform(list_of_predictions)
    df = pd.DataFrame({'Credit_Score': preds}, index=X_test.index)
    df.to_csv('sandbox_submission.csv')

# %%
generate_submission()
